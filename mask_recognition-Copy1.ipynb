# %%
# import the necessary packages
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import pandas as pd
from sklearn.model_selection import train_test_split
import shutil
import time
import copy

# %%
#Creating image datasets an data loaders for train and test using the experiments folder split
experiments_path = '/experiments/dest_folder/'
data_path = '/experiments/data/'

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.ToTensor(), 
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]), 
    'test' : transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

# %%
def get_train_files_path(experiments_path, data_path, phase):
    if phase == 'train':
        file_name = 'train.csv'
    elif phase == 'test':
        file_name = 'test.csv'
    else:
        print("phase can only have train and test as parameter values")
        exit()
    file_path = os.path.join(experiments_path, file_name)
    train_df = pd.read_csv(file_path, delimiter=',')
    files_path = []
    fonts_class = []
    for row in train_df.iterrows():
        files_path.append(os.path.join(data_path, row[1]['class'], row[1]['filename']))
        fonts_class.append(row[1]['class'])
    
    return files_path, fonts_class

# %%
def copy_images_to_path(file_path, file_class, destination_dir):
    font_folder = os.path.join(destination_dir, file_class)
    if os.path.exists(font_folder) == False:
        os.makedirs(font_folder)
    
    print("File being copied from {}:{}".format(file_path, font_folder))
    shutil.copy(file_path, font_folder)
    #shutil.copyfile(file_path, font_folder)

# %%
X_train, y_train = get_train_files_path(experiments_path, data_path, phase='train')
X_test, y_test = get_train_files_path(experiments_path, data_path, phase='test')

# %%
train_dir = os.path.join(experiments_path, 'train')
test_dir = os.path.join(experiments_path, 'test')

if not os.path.exists(train_dir):
    os.makedirs(train_dir)

if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# %%
for file_path, font_class in zip(X_train, y_train):
    copy_images_to_path(file_path, font_class, train_dir)
# Out:
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/0-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/10-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/100-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/101-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/103-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/104-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/105-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/107-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/108-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/109-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/112-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/113-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/115-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/116-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/117-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/118-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/119-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/12-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/120-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/122-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/123-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/124-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/125-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/126-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/128-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/129-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/13-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/131-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/132-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/133-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/134-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/135-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/136-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/137-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/138-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/139-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/14-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/140-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/143-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/144-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/147-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/148-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/15-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/150-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/151-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/152-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/153-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/154-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/155-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/156-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/158-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/159-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/16-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/161-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/162-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/163-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/168-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/169-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/17-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/170-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/171-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/172-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/173-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/175-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/176-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/177-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/179-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/18-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/180-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/182-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/183-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/185-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/187-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/189-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/19-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/190-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/192-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/194-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/195-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/196-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/197-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/198-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/2-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/200-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/202-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/203-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/205-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/206-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/209-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/21-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/212-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/214-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/215-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/217-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/218-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/221-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/222-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/223-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/224-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/225-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/226-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/227-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/228-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/231-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/232-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/233-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/234-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/235-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/236-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/237-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/238-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/239-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/24-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/240-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/241-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/242-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/245-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/246-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/251-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/252-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/253-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/254-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/255-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/256-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/257-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/259-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/260-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/261-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/263-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/267-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/269-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/27-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/270-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/272-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/273-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/274-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/275-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/276-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/277-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/279-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/281-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/282-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/284-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/286-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/288-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/289-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/29-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/290-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/291-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/293-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/294-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/296-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/297-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/298-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/299-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/3-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/301-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/302-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/304-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/305-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/309-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/31-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/311-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/313-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/314-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/315-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/32-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/322-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/323-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/324-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/327-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/33-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/330-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/331-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/333-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/334-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/335-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/336-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/338-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/339-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/343-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/346-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/347-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/348-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/349-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/35-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/351-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/353-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/355-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/356-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/358-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/359-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/364-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/365-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/366-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/368-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/37-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/375-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/376-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/377-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/378-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/379-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/38-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/381-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/383-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/384-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/386-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/387-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/39-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/390-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/392-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/393-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/394-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/395-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/396-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/397-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/398-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/399-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/4-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/40-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/401-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/405-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/406-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/407-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/408-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/41-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/411-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/413-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/414-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/415-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/416-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/417-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/with_mask/418-with-mask.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/with_mask
# ...
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_312.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_314.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_315.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_316.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_317.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_318.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_319.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_32.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_33.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_35.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_36.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_37.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_38.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_39.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_4.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_40.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_41.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_42.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_43.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_44.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_45.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_48.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_5.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_50.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_51.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_52.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_53.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_54.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_55.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_56.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_57.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_58.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_59.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_60.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_61.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_62.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_63.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_64.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_65.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_66.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_67.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_68.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_69.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_7.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_70.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_71.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_72.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_73.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_74.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_76.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_77.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_78.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_79.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_80.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_81.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_82.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_83.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_84.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_85.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_86.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_87.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_88.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_89.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_90.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_91.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_92.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_93.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_94.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_95.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_96.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_97.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_98.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask
# File being copied from /Users/kellymclean/face_recognition/observations/experiments/data/without_mask/augmented_image_99.jpg:/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask

# %%
image_datasets = {x: datasets.ImageFolder(os.path.join(experiments_path, x), data_transforms[x]) for x in ['train', 'test']}

# %%
image_datasets['train']
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1315
#     Root location: /Users/kellymclean/face_recognition/observations/experiments/dest_folder/train
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
image_datasets['test']
# Out:
# Dataset ImageFolder
#     Number of datapoints: 194
#     Root location: /Users/kellymclean/face_recognition/observations/experiments/dest_folder/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=PIL.Image.BILINEAR)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], 
                                             batch_size=16, 
                                             shuffle=True, 
                                             num_workers=4) 
               for x in ['train', 'test']}

# %%
dataloaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x155e40fd0>,
#  'test': <torch.utils.data.dataloader.DataLoader at 0x155a0c790>}

# %%
class_names = image_datasets['train'].classes

# %%
class_names
# Out:
# ['with_mask', 'without_mask']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cpu')

# %%
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}

# %%
#Visualizing images
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.figure(figsize=(20,20))
    plt.imshow(inp)

    if title is not None:
        plt.title(title)
    plt.pause(0.001)

# %%
inputs, classes = next(iter(dataloaders['train']))
out = torchvision.utils.make_grid(inputs)

# %%
imshow(out, title=[class_names[x] for x in classes])

# %%
#Training the model
def train_model(model, criterion, optimizer, scheduler, num_epochs=20):
    since = time.time()
    best_acc = 0.0
    best_model = copy.deepcopy(model.state_dict())
    
    new_freeze_state = None
    prev_freeze_state = False
    for epoch in range(num_epochs):
        print("Epoch {}/{}".format(epoch, num_epochs - 1))
        print('-' * 10)
        
        for phase in ['train', 'test']:
            if phase == 'train':
                scheduler.step()
                model.train()
            else:
                model.eval()
                
            running_loss = 0.0
            running_corrects = 0
        
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                optimizer.zero_grad()
                
                
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                        
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            
            print('{} Loss: {:.4f} Acc:{:.4f}'.format(
                phase, epoch_loss, epoch_acc))
            
            
            if phase == 'test' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model = copy.deepcopy(model.state_dict())
            
            print()
    
    time_elapsed = time.time() - since
    print('Training complete in {:0f}m {:.0f}s'.format(
    time_elapsed // 60, time_elapsed % 60))
    print('Best val acc: {:4f}'.format(best_acc))
    
    model.load_state_dict(best_model)
    return model

# %%
import ssl

# %%
ssl._create_default_https_context = ssl._create_unverified_context

# %%
model_ft = models.resnet101(pretrained=True)

num_frts = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_frts, len(class_names))

model_ft = model_ft.to(device)
criterion = nn.CrossEntropyLoss()

#optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.01, momentum=0.9)
optimizer_ft = optim.Adagrad(model_ft.parameters(), lr=0.001)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# /Users/kellymclean/opt/anaconda3/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:123: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /Users/kellymclean/opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py:2929: UserWarning: image file could not be identified because WEBP support not installed
#   warnings.warn(message)
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-32-4d6bc9f62c42> in <module>
# ----> 1 model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=20)
#
# <ipython-input-28-a5eb21cc3d5c> in train_model(model, criterion, optimizer, scheduler, num_epochs)
#      21             running_corrects = 0
#      22
# ---> 23             for inputs, labels in dataloaders[phase]:
#      24                 inputs = inputs.to(device)
#      25                 labels = labels.to(device)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     854             else:
#     855                 del self._task_info[idx]
# --> 856                 return self._process_data(data)
#     857
#     858     def _try_put_index(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#     879         self._try_put_index()
#     880         if isinstance(data, ExceptionWrapper):
# --> 881             data.reraise()
#     882         return data
#     883
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/_utils.py in reraise(self)
#     393             # (https://bugs.python.org/issue2651), so we work around it.
#     394             msg = KeyErrorMessage(msg)
# --> 395         raise self.exc_type(msg)
#
# UnidentifiedImageError: Caught UnidentifiedImageError in DataLoader worker process 3.
# Original Traceback (most recent call last):
#   File "/Users/kellymclean/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/_utils/worker.py", line 178, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/Users/kellymclean/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/Users/kellymclean/opt/anaconda3/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/Users/kellymclean/opt/anaconda3/lib/python3.7/site-packages/torchvision/datasets/folder.py", line 135, in __getitem__
#     sample = self.loader(path)
#   File "/Users/kellymclean/opt/anaconda3/lib/python3.7/site-packages/torchvision/datasets/folder.py", line 171, in default_loader
#     return pil_loader(path)
#   File "/Users/kellymclean/opt/anaconda3/lib/python3.7/site-packages/torchvision/datasets/folder.py", line 153, in pil_loader
#     img = Image.open(f)
#   File "/Users/kellymclean/opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py", line 2931, in open
#     "cannot identify image file %r" % (filename if filename else fp)
# PIL.UnidentifiedImageError: cannot identify image file <_io.BufferedReader name='/Users/kellymclean/face_recognition/observations/experiments/dest_folder/train/without_mask/indian-ethnicity-cheerful-confident-studio-260nw-552325924.jpg'>

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    #fig = plt.figure(figsize=(10,10))
    
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            print(preds,"predicitons")
            
            
            for j in range(inputs.size()[0]):
                images_so_far +=1
                #ax = plt.subplot(num_images//len(labels)-1, len(labels), images_so_far)
                #ax.axis('off')
                #ax.set_title('true: {} predicted: {}'.format(class_names[labels[j]], class_names[preds[j]]))
                print('true: {} predicted: {}'.format(class_names[labels[j]], class_names[preds[j]]))
                #imshow(inputs.cpu().data[j])
                
                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
torch.save(model_ft, 'mask1_model_resnet101.pth')

# %%
visualize_model(model_ft)
